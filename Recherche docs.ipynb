# %%
import os
import re 

path = r'S:\P_Regulation_Presse\04. PEREQUATION'

for root, folders, files in os.walk(path):
    if len(files) > 0:
        for file in files:
            pat = re.compile(r'consult', re.IGNORECASE)
            if re.search(pat, file):
                print(os.path.join(root, file))
# Out:
# S:\P_Regulation_Presse\04. PEREQUATION\1. Elements juridiques\1. Consultations publiques\1. Premiere CP\1. Publication\consult-perequation-entreprises-presse_dec2020.pdf
# S:\P_Regulation_Presse\04. PEREQUATION\1. Elements juridiques\1. Consultations publiques\1. Premiere CP\1. Publication\Proposition de Péréquation - consultation publique - V9.docx
# S:\P_Regulation_Presse\04. PEREQUATION\1. Elements juridiques\1. Consultations publiques\1. Premiere CP\1. Publication\CP publiée\Proposition de Péréquation - consultation publique - V9.docx
# S:\P_Regulation_Presse\04. PEREQUATION\1. Elements juridiques\1. Consultations publiques\1. Premiere CP\1. Publication\CP publiée\~$oposition de Péréquation - consultation publique - V9.docx
# S:\P_Regulation_Presse\04. PEREQUATION\1. Elements juridiques\1. Consultations publiques\1. Premiere CP\2. Contributions\contributions-consult-perequation-entreprises-presse-dec2020_juil2021.zip
# ...
